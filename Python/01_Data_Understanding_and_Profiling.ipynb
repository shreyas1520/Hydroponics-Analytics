# %% [markdown]
# # Dataset Overview
#
# ## Objective
#
# Understand the structure, size and quality of the dataset before performing analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:/Users/Hp/Downloads/Hydroponics_Analytics_Dataset_10_Days.xlsx")

# %% [markdown]
# # Dataset Overview

# %%
df.head(10)
# Out:
#           Timestamp    pH  TDS_ppm  Air_Temperature_C  Water_Temperature_C  \
# 0  2026-03-01 00:00  6.16      709               26.1                 23.9
# 1  2026-03-01 01:00  6.26      704               26.2                 24.3
# 2  2026-03-01 02:00  6.15      718               25.9                 23.6
# 3  2026-03-01 03:00  6.22      715               25.5                 23.3
# 4  2026-03-01 04:00  6.26      707               25.9                 23.8
# 5  2026-03-01 05:00  6.27      712               25.8                 23.6
# 6  2026-03-01 06:00  6.26      710               26.6                 24.4
# 7  2026-03-01 07:00  6.28      714               27.2                 25.3
# 8  2026-03-01 08:00  6.22      713               27.1                 25.2
# 9  2026-03-01 09:00  6.23      711               26.7                 24.4
#
#    Humidity_pct  Water_Level_pct Water_Pump Nutrient_Pump Humidifier  \
# 0            62              100        OFF            ON        OFF
# ...

# %%
df.tail()
# Out:
#             Timestamp    pH  TDS_ppm  Air_Temperature_C  Water_Temperature_C  \
# 235  2026-03-10 19:00  6.37      722               27.7                 25.5
# 236  2026-03-10 20:00  6.33      722               27.7                 25.8
# 237  2026-03-10 21:00  6.42      733               27.9                 25.9
# 238  2026-03-10 22:00  6.38      723               27.7                 25.7
# 239  2026-03-10 23:00  6.40      729               28.2                 26.2
#
#      Humidity_pct  Water_Level_pct Water_Pump Nutrient_Pump Humidifier  \
# 235            64               53        OFF           OFF        OFF
# 236            66               51        OFF           OFF        OFF
# 237            66               49        OFF           OFF        OFF
# 238            66               47        OFF           OFF        OFF
# 239            64               45        OFF           OFF        OFF
#
#     Exhaust_Fan   Alert
# 235         OFF  Normal
# 236         OFF  Normal
# ...

# %%
df.shape
# Out:
# (240, 12)

# %% [markdown]
# ### Interpretation
#
# The dataset contains 240 observations and 12 variables.
# The number of observations corresponds to 10 days of hourly monitoring.
#
# Business Insight
#
# The monitoring frequency is sufficient to identify operational trends and threshold violations.

# %%
df.columns
# Out:
# Index(['Timestamp', 'pH', 'TDS_ppm', 'Air_Temperature_C',
#        'Water_Temperature_C', 'Humidity_pct', 'Water_Level_pct', 'Water_Pump',
#        'Nutrient_Pump', 'Humidifier', 'Exhaust_Fan', 'Alert'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            240 non-null    str
#  1   pH                   240 non-null    float64
#  2   TDS_ppm              240 non-null    int64
#  3   Air_Temperature_C    240 non-null    float64
#  4   Water_Temperature_C  240 non-null    float64
#  5   Humidity_pct         240 non-null    int64
#  6   Water_Level_pct      240 non-null    int64
#  7   Water_Pump           240 non-null    str
#  8   Nutrient_Pump        240 non-null    str
#  9   Humidifier           240 non-null    str
#  10  Exhaust_Fan          240 non-null    str
#  11  Alert                240 non-null    str
# dtypes: float64(3), int64(3), str(6)
# memory usage: 22.6 KB

# %% [markdown]
# # Data Quality

# %%
df.isnull().sum()
# Out:
# Timestamp              0
# pH                     0
# TDS_ppm                0
# Air_Temperature_C      0
# Water_Temperature_C    0
# Humidity_pct           0
# Water_Level_pct        0
# Water_Pump             0
# Nutrient_Pump          0
# Humidifier             0
# Exhaust_Fan            0
# Alert                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Timestamp                  str
# pH                     float64
# TDS_ppm                  int64
# Air_Temperature_C      float64
# Water_Temperature_C    float64
# Humidity_pct             int64
# Water_Level_pct          int64
# Water_Pump                 str
# Nutrient_Pump              str
# Humidifier                 str
# Exhaust_Fan                str
# Alert                      str
# dtype: object

# %%
df.describe()
# Out:
#                pH     TDS_ppm  Air_Temperature_C  Water_Temperature_C  \
# count  240.000000  240.000000         240.000000           240.000000
# mean     6.314458  721.545833          30.072917            27.858750
# std      0.084416    7.545537           3.050368             2.722771
# min      6.120000  702.000000          25.500000            23.300000
# 25%      6.250000  716.000000          27.600000            25.500000
# 50%      6.320000  722.000000          29.200000            27.200000
# 75%      6.370000  727.000000          32.800000            30.650000
# max      6.470000  738.000000          37.500000            32.000000
#
#        Humidity_pct  Water_Level_pct
# count    240.000000       240.000000
# mean      63.850000        70.812500
# std        2.583015        14.781047
# min       58.000000        36.000000
# 25%       62.000000        59.000000
# 50%       64.000000        70.500000
# 75%       66.000000        83.000000
# ...

# %% [markdown]
# # Summary Statistics

# %%
df.describe(include=["object","string"])
# Out:
#        Water_Pump Nutrient_Pump Humidifier Exhaust_Fan   Alert
# count         240           240        240         240     240
# unique          2             2          2           2       6
# top           OFF           OFF        OFF         OFF  Normal
# freq          237           193        192         168     129

# %% [markdown]
# # Unique Values

# %%
df["Alert"].value_counts()
# Out:
# Alert
# Normal                                        129
# High Temperature                               62
# Low TDS                                        39
# Low TDS; High Temperature                       7
# Low Water Level; High Temperature               2
# Low Water Level; Low TDS; High Temperature      1
# Name: count, dtype: int64

# %%
df["Water_Pump"].value_counts()
# Out:
# Water_Pump
# OFF    237
# ON       3
# Name: count, dtype: int64

# %%
df["Nutrient_Pump"].value_counts()
# Out:
# Nutrient_Pump
# OFF    193
# ON      47
# Name: count, dtype: int64

# %%
df["Humidifier"].value_counts()
# Out:
# Humidifier
# OFF    192
# ON      48
# Name: count, dtype: int64

# %%
df["Exhaust_Fan"].value_counts()
# Out:
# Exhaust_Fan
# OFF    168
# ON      72
# Name: count, dtype: int64

# %% [markdown]
# # Check Data Range

# %%
df.min(numeric_only=True)
# Out:
# pH                       6.12
# TDS_ppm                702.00
# Air_Temperature_C       25.50
# Water_Temperature_C     23.30
# Humidity_pct            58.00
# Water_Level_pct         36.00
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# pH                       6.47
# TDS_ppm                738.00
# Air_Temperature_C       37.50
# Water_Temperature_C     32.00
# Humidity_pct            69.00
# Water_Level_pct        100.00
# dtype: float64

# %% [markdown]
# # Convert Timestamp

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            240 non-null    datetime64[us]
#  1   pH                   240 non-null    float64
#  2   TDS_ppm              240 non-null    int64
#  3   Air_Temperature_C    240 non-null    float64
#  4   Water_Temperature_C  240 non-null    float64
#  5   Humidity_pct         240 non-null    int64
#  6   Water_Level_pct      240 non-null    int64
#  7   Water_Pump           240 non-null    str
#  8   Nutrient_Pump        240 non-null    str
#  9   Humidifier           240 non-null    str
#  10  Exhaust_Fan          240 non-null    str
#  11  Alert                240 non-null    str
# dtypes: datetime64[us](1), float64(3), int64(3), str(5)
# memory usage: 22.6 KB

# %% [markdown]
# ## Initial Observations
#
# - Dataset contains 240 hourly observations collected over 10 days.
# - No missing values were detected.
# - No duplicate records were found.
# - pH values remained within the acceptable range.
# - Temperature increased significantly during Days 4–6.
# - Water level gradually decreased before pump activation.
# - Nutrient pump was activated only when TDS dropped below the threshold.

# %% [markdown]
# ## Memory Usage

# %%
df.memory_usage(deep=True)
# Out:
# Index                    132
# Timestamp               1920
# pH                      1920
# TDS_ppm                 1920
# Air_Temperature_C       1920
# Water_Temperature_C     1920
# Humidity_pct            1920
# Water_Level_pct         1920
# Water_Pump             12477
# Nutrient_Pump          12433
# Humidifier             12432
# Exhaust_Fan            12408
# Alert                  14082
# dtype: int64

# %%
df.memory_usage(deep=True).sum()
# Out:
# np.int64(77404)

# %% [markdown]
# ## Correlation Preview

# %%
df.corr(numeric_only=True)
# Out:
#                            pH   TDS_ppm  Air_Temperature_C  \
# pH                   1.000000  0.126357           0.015875
# TDS_ppm              0.126357  1.000000           0.059016
# Air_Temperature_C    0.015875  0.059016           1.000000
# Water_Temperature_C  0.007229  0.085496           0.985022
# Humidity_pct         0.258676  0.294891          -0.598144
# Water_Level_pct     -0.184094  0.007899          -0.319389
#
#                      Water_Temperature_C  Humidity_pct  Water_Level_pct
# pH                              0.007229      0.258676        -0.184094
# TDS_ppm                         0.085496      0.294891         0.007899
# Air_Temperature_C               0.985022     -0.598144        -0.319389
# Water_Temperature_C             1.000000     -0.577606        -0.288633
# Humidity_pct                   -0.577606      1.000000         0.104795
# Water_Level_pct                -0.288633      0.104795         1.000000
